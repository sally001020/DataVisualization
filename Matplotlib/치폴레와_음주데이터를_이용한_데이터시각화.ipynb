# %% [markdown]
# <a href="https://colab.research.google.com/github/sally001020/DataVisualization/blob/main/%EC%B9%98%ED%8F%B4%EB%A0%88%EC%99%80_%EC%9D%8C%EC%A3%BC%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%A5%BC_%EC%9D%B4%EC%9A%A9%ED%95%9C_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

file_path = 'chipotle.tsv'
chipo = pd.read_csv(file_path, sep = '\t')

print(chipo.shape)
print("--------------------------------")
print(chipo.info())
# Out:
# (4622, 5)
# --------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB
# None

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
chipo['order_id'] = chipo['order_id'].astype(str)

print(chipo.describe())

print(len(chipo['order_id'].unique()))
print(len(chipo['item_name'].unique()))
# Out:
#           quantity
# count  4622.000000
# mean      1.075725
# std       0.410186
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max      15.000000
# 1834
# 50

# %%
import pandas as pd

file_path = 'chipotle.tsv'
chipo = pd.read_csv(file_path, sep = '\t')

def splt_firstchar(x):
  return float(x[1:])

chipo['item_price'] = chipo['item_price'].apply(splt_firstchar)
chipo.describe()
# Out:
#           order_id     quantity   item_price
# count  4622.000000  4622.000000  4622.000000
# mean    927.254868     1.075725     7.464336
# std     528.890796     0.410186     4.245557
# min       1.000000     1.000000     1.090000
# 25%     477.250000     1.000000     3.390000
# 50%     926.000000     1.000000     8.750000
# 75%    1393.000000     1.000000     9.250000
# max    1834.000000    15.000000    44.250000

# %%
import pandas as pd

file_path = 'chipotle.tsv'
chipo = pd.read_csv(file_path, sep = '\t')

item_unique = chipo['item_name'].unique()
item_count = chipo['item_name'].value_counts()

print(item_unique)
print('-------------------------')
print(item_count)
# Out:
# ['Chips and Fresh Tomato Salsa' 'Izze' 'Nantucket Nectar'
#  'Chips and Tomatillo-Green Chili Salsa' 'Chicken Bowl' 'Side of Chips'
#  'Steak Burrito' 'Steak Soft Tacos' 'Chips and Guacamole'
#  'Chicken Crispy Tacos' 'Chicken Soft Tacos' 'Chicken Burrito'
#  'Canned Soda' 'Barbacoa Burrito' 'Carnitas Burrito' 'Carnitas Bowl'
#  'Bottled Water' 'Chips and Tomatillo Green Chili Salsa' 'Barbacoa Bowl'
#  'Chips' 'Chicken Salad Bowl' 'Steak Bowl' 'Barbacoa Soft Tacos'
#  'Veggie Burrito' 'Veggie Bowl' 'Steak Crispy Tacos'
#  'Chips and Tomatillo Red Chili Salsa' 'Barbacoa Crispy Tacos'
#  'Veggie Salad Bowl' 'Chips and Roasted Chili-Corn Salsa'
#  'Chips and Roasted Chili Corn Salsa' 'Carnitas Soft Tacos'
#  'Chicken Salad' 'Canned Soft Drink' 'Steak Salad Bowl'
#  '6 Pack Soft Drink' 'Chips and Tomatillo-Red Chili Salsa' 'Bowl'
#  'Burrito' 'Crispy Tacos' 'Carnitas Crispy Tacos' 'Steak Salad'
#  'Chips and Mild Fresh Tomato Salsa' 'Veggie Soft Tacos'
# ...

# %%
import pandas as pd

file_path = 'chipotle.tsv'
chipo = pd.read_csv(file_path, sep = '\t')

item_count = chipo['item_name'].value_counts()[:10]

for idx, (val, cnt) in enumerate(item_count.iteritems(), 1):
  print("Top", idx, ":", val, cnt)
# Out:
# Top 1 : Chicken Bowl 726
# Top 2 : Chicken Burrito 553
# Top 3 : Chips and Guacamole 479
# Top 4 : Steak Burrito 368
# Top 5 : Canned Soft Drink 301
# Top 6 : Steak Bowl 211
# Top 7 : Chips 211
# Top 8 : Bottled Water 162
# Top 9 : Chicken Soft Tacos 115
# Top 10 : Chips and Fresh Tomato Salsa 110

# %%
order_count = chipo.groupby('item_name').count()
order_count[:12]
# Out:
#                        order_id  quantity  choice_description  item_price
# item_name
# 6 Pack Soft Drink            54        54                  54          54
# Barbacoa Bowl                66        66                  66          66
# Barbacoa Burrito             91        91                  91          91
# Barbacoa Crispy Tacos        11        11                  11          11
# Barbacoa Salad Bowl          10        10                  10          10
# Barbacoa Soft Tacos          25        25                  25          25
# Bottled Water               162       162                   0         162
# Bowl                          2         2                   2           2
# Burrito                       6         6                   6           6
# Canned Soda                 104       104                 104         104
# Canned Soft Drink           301       301                 301         301
# Carnitas Bowl                68        68                  68          68

# %%
order_count = chipo.groupby('item_name').count()
order_count[:12]
print("------------------------------------")

order_count = chipo.groupby('item_name')['order_id'].count()
order_count[:12]
print("------------------------------------")
item_quantity = chipo.groupby('item_name')['quantity'].sum()
item_quantity[:10]
# Out:
# ------------------------------------
# ------------------------------------
# item_name
# 6 Pack Soft Drink         55
# Barbacoa Bowl             66
# Barbacoa Burrito          91
# Barbacoa Crispy Tacos     12
# Barbacoa Salad Bowl       10
# Barbacoa Soft Tacos       25
# Bottled Water            211
# Bowl                       4
# Burrito                    6
# Canned Soda              126
# Name: quantity, dtype: int64

# %%
import pandas as pd

file_path = 'chipotle.tsv'
chipo = pd.read_csv(file_path, sep = '\t')

order_count = chipo.groupby('item_name').count()
order_count[:12]
# Out:
#                        order_id  quantity  choice_description  item_price
# item_name
# 6 Pack Soft Drink            54        54                  54          54
# Barbacoa Bowl                66        66                  66          66
# Barbacoa Burrito             91        91                  91          91
# Barbacoa Crispy Tacos        11        11                  11          11
# Barbacoa Salad Bowl          10        10                  10          10
# Barbacoa Soft Tacos          25        25                  25          25
# Bottled Water               162       162                   0         162
# Bowl                          2         2                   2           2
# Burrito                       6         6                   6           6
# Canned Soda                 104       104                 104         104
# Canned Soft Drink           301       301                 301         301
# Carnitas Bowl                68        68                  68          68

# %%
item_quantity = chipo.groupby('item_name')['quantity'].sum()
item_quantity[:10]
# Out:
# item_name
# 6 Pack Soft Drink         55
# Barbacoa Bowl             66
# Barbacoa Burrito          91
# Barbacoa Crispy Tacos     12
# Barbacoa Salad Bowl       10
# Barbacoa Soft Tacos       25
# Bottled Water            211
# Bowl                       4
# Burrito                    6
# Canned Soda              126
# Name: quantity, dtype: int64

# %%
import pandas as pd

file_path = 'chipotle.tsv'
chipo = pd.read_csv(file_path, sep = '\t')
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))

item_quantity = chipo.groupby('item_name')['quantity'].sum()

chipo.groupby('order_id')['item_price'].sum().mean()
# Out:
# 18.81142857142869

# %%
import pandas as pd

file_path = 'chipotle.tsv'
chipo = pd.read_csv(file_path, sep = '\t')
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))

chipo_orderid_group = chipo.groupby('order_id').sum()
print(chipo_orderid_group)

results = chipo_orderid_group[chipo_orderid_group.item_price >= 15]
print('-----------------')
print(results[:10])
# Out:
#           quantity  item_price
# order_id
# 1                4       11.56
# 2                2       16.98
# 3                2       12.67
# 4                2       21.00
# 5                2       13.70
# ...            ...         ...
# 1830             2       23.00
# 1831             3       12.90
# 1832             2       13.20
# 1833             2       23.50
# 1834             3       28.75
#
# [1834 rows x 2 columns]
# -----------------
#           quantity  item_price
# order_id
# 2                2       16.98
# 4                2       21.00
# 6                2       17.50
# 7                2       15.70
# 18               4       24.90
# 20               4       36.20
# 21               3       23.36
# 26               2       20.50
# 28               4       33.70
# 29               2       17.98

# %%
chipo_one_item = chipo[chipo.quantity == 1]

price_per_item = chipo_one_item.groupby('item_name').min()
price_per_item.sort_values(by = 'item_price', ascending = False)[:10] #내림차순 비싼거 -> 싼거
# Out:
#                        order_id  quantity  \
# item_name
# Steak Salad Bowl            250         1
# Barbacoa Salad Bowl         501         1
# Carnitas Salad Bowl         468         1
# Carnitas Soft Tacos         103         1
# Carnitas Crispy Tacos       230         1
# Steak Soft Tacos              4         1
# Carnitas Salad             1500         1
# Carnitas Bowl                17         1
# Barbacoa Soft Tacos          26         1
# Barbacoa Crispy Tacos        75         1
#
#                                                       choice_description  \
# item_name
# Steak Salad Bowl                           [Fresh Tomato Salsa, Lettuce]
# Barbacoa Salad Bowl                      [Fresh Tomato Salsa, Guacamole]
# Carnitas Salad Bowl    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...
# Carnitas Soft Tacos    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...
# Carnitas Crispy Tacos  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# ...

# %%
import pandas as pd

file_path = 'chipotle.tsv'
chipo = pd.read_csv(file_path, sep = '\t')
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))

chipo.groupby('order_id').sum().sort_values(by='item_price', ascending=False)[:5]
# Out:
#           quantity  item_price
# order_id
# 926             23      205.25
# 1443            35      160.74
# 1483            14      139.00
# 691             11      118.25
# 1786            20      114.30

# %%
import pandas as pd

file_path = 'chipotle.tsv'
chipo = pd.read_csv(file_path, sep = '\t')
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))

chipo_salad = chipo[chipo['item_name']=="Veggie Salad Bowl"]
chipo_salad.head(5)
# Out:
#      order_id  quantity          item_name  \
# 186        83         1  Veggie Salad Bowl
# 295       128         1  Veggie Salad Bowl
# 455       195         1  Veggie Salad Bowl
# 496       207         1  Veggie Salad Bowl
# 960       394         1  Veggie Salad Bowl
#
#                                     choice_description  item_price
# 186  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 295  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...       11.25
# 455  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 496  [Fresh Tomato Salsa, [Rice, Lettuce, Guacamole...       11.25
# 960  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_path = 'drinks.csv'
drinks = pd.read_csv(file_path)

print(drinks.info())

drinks.head(10)

drinks.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB
# None
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# ...

# %%
corr = drinks[['beer_servings','wine_servings']].corr(method='pearson')
print(corr)
# Out:
#                beer_servings  wine_servings
# beer_servings       1.000000       0.527172
# wine_servings       0.527172       1.000000

# %%
cols = ['beer_servings','spirit_servings','wine_servings','total_litres_of_pure_alcohol']
corr = drinks[cols].corr(method='pearson')
print(corr)
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# beer_servings                      1.000000         0.458819       0.527172
# spirit_servings                    0.458819         1.000000       0.194797
# wine_servings                      0.527172         0.194797       1.000000
# total_litres_of_pure_alcohol       0.835839         0.654968       0.667598
#
#                               total_litres_of_pure_alcohol
# beer_servings                                     0.835839
# spirit_servings                                   0.654968
# wine_servings                                     0.667598
# total_litres_of_pure_alcohol                      1.000000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

file_path = 'drinks.csv'
drinks = pd.read_csv(file_path)

#sns.set(style='whitegrid', context='notebook')
sns.pairplot(drinks[['beer_servings', 'spirit_servings', 
                     'wine_servings', 'total_litres_of_pure_alcohol']], height = 2.5)

plt.show()

# %%
import pandas as pd

file_path = 'drinks.csv'
drinks = pd.read_csv(file_path)

print(drinks.isnull().sum())
print('-------------------------')
drinks['continent'] = drinks['continent'].fillna('OT')
print(drinks.isnull().sum())
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64
# -------------------------
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
drinks['continent'] = drinks['continent'].fillna('OT')

labels = drinks['continent'].value_counts().index.tolist()
print(labels)
fracs1 = drinks['continent'].value_counts().values.tolist()
print(fracs1)
explode = (0,0,0,0.25,0,0)

plt.pie(fracs1, explode=explode, labels = labels, autopct='%.0f%%', shadow=True)
plt.title('null data to \'OT\'')
plt.show()
# Out:
# ['AF', 'EU', 'AS', 'OT', 'OC', 'SA']
# [53, 45, 44, 23, 16, 12]

# %%
import pandas as pd
import matplotlib.pyplot as plt
drinks['continent'] = drinks['continent'].fillna('OT')

result = drinks.groupby('continent').spirit_servings.agg(['mean','min','max','sum','count'])
print(result)
# Out:
#                  mean  min  max   sum  count
# continent
# AF          16.339623    0  152   866     53
# AS          60.840909    0  326  2677     44
# EU         132.555556    0  373  5965     45
# OC          58.437500    0  254   935     16
# OT         165.739130   68  438  3812     23
# SA         114.750000   25  302  1377     12

# %%
import pandas as pd
import matplotlib.pyplot as plt
drinks['continent'] = drinks['continent'].fillna('OT')

total_mean = drinks.total_litres_of_pure_alcohol.mean()
continent_mean = drinks.groupby('continent')['total_litres_of_pure_alcohol'].mean()
continent_over_mean = continent_mean[continent_mean >= total_mean]
print(continent_over_mean)
# Out:
# continent
# EU    8.617778
# OT    5.995652
# SA    6.308333
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
beer_continent = drinks.groupby('continent').beer_servings.mean().max()
print(beer_continent)

beer_continent = drinks.groupby('continent').beer_servings.mean().idxmax()
print(beer_continent)
# Out:
# 193.77777777777777
# EU

# %%
import pandas as pd
import matplotlib.pyplot as plt
drinks['continent'] = drinks['continent'].fillna('OT')

total_mean = drinks.total_litres_of_pure_alcohol.mean()
continent_mean = drinks.groupby('continent')['total_litres_of_pure_alcohol'].mean()
continent_over_mean = continent_mean[continent_mean >= total_mean]

continents = continent_mean.index.tolist()

continents.append('mean')

x_pos = np.arange(len(continents))
alcohol = continent_mean.tolist()

alcohol.append(total_mean)


bar_list = plt.bar(x_pos, alcohol, align='center', alpha = 0.5)
bar_list[len(continents) - 1].set_color('r')
plt.plot([0,len(continents) - 1], [total_mean, total_mean], "k--")
plt.xticks(x_pos, continents)
plt.ylabel('total_litres_of_pure_alcohol')
plt.title('total_litres_of_pure_alcohol by Continent')

plt.show()

# %%
from scipy import stats
file_path = 'drinks.csv'
drinks = pd.read_csv(file_path)
drinks['continent'] = drinks['continent'].fillna('OT')

drinks['total_servings'] = drinks['beer_servings']+drinks['wine_servings']+drinks['spirit_servings']

drinks['alcohol_rate'] = drinks['total_litres_of_pure_alcohol'] / drinks['total_servings']

drinks['alcohol_rate'] = drinks['alcohol_rate'].fillna(0)

country_with_rank = drinks[['country', 'alcohol_rate']]
country_with_rank = country_with_rank.sort_values(by=['alcohol_rate'], ascending = 0)
country_with_rank.head(5)

country_list = country_with_rank.country.tolist()
x_pos = np.arange(len(country_list))
rank = country_with_rank.alcohol_rate.tolist()

bar_list = plt.bar(x_pos, rank)
plt.ylabel('alcohol rate')
plt.title('liquor drink rank by country')
plt.axis([0,200,0,0.3])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

file_path='drinks.csv'
drinks = pd.read_csv(file_path)
drinks['continent'] = drinks['continent'].fillna('OT')

africa = drinks.loc[drinks['continent']=='AF']
europe = drinks.loc[drinks['continent']=='EU']
africa
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 2                     Algeria             25                0             14
# 4                      Angola            217               57             45
# 18                      Benin             34                4             13
# 22                   Botswana            173               35             35
# 26               Burkina Faso             25                7              7
# 27                    Burundi             88                0              0
# 28              Cote d'Ivoire             37                1              7
# 29                 Cabo Verde            144               56             16
# 31                   Cameroon            147                1              4
# 33   Central African Republic             17                2              1
# 34                       Chad             15                1              1
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

file_path='drinks.csv'
drinks = pd.read_csv(file_path)
drinks['continent'] = drinks['continent'].fillna('OT')

drinks['total_servings'] = drinks['beer_servings'] + drinks['wine_servings'] + drinks['spirit_servings']

drinks['alcohol_rate'] = drinks['total_litres_of_pure_alcohol'] / drinks['total_servings']

drinks['alcohol_rate'] = drinks['alcohol_rate'].fillna(0)

country_with_rank = drinks[['country', 'alcohol_rate']]
country_with_rank = country_with_rank.sort_values(by=['alcohol_rate'], ascending=0)
country_with_rank.head(5)

country_list = country_with_rank.country.tolist()
x_pos = np.arange(len(country_list))
rank = country_with_rank.alcohol_rate.tolist()

bar_list = plt.bar(x_pos, rank)
plt.ylabel('alcohol rate')
plt.title('liquor drink rank by country')
plt.axis([0,200,0,0.3])

bar_list[country_list.index("South Korea")].set_color('r') #한국 차트 빨간색으로 색 변경

korea_rank = country_list.index("South Korea") # 14가 저장된다

korea_alc_rate = country_with_rank[country_with_rank['country'] == 'South Korea']['alcohol_rate'].values[0]

plt.annotate('South Korea : ' + str(korea_rank + 1), #인덱스는 0부터 시작하기 때문에 1을 더해준다.
             xy = (korea_rank, korea_alc_rate), #화살표 끝 방향
             xytext=(korea_rank + 10, korea_alc_rate + 0.05),#텍스트 찍히는 위치
             arrowprops = dict(facecolor='red', shrink=0.05))
plt.show()
